# %% [markdown]
# # Welcome!
# Below, we will learn to implement and train a policy to play atari-pong, using only the pixels as input. We will use convolutional neural nets, multiprocessing, and pytorch to implement and train our policy. Let's get started!
#
# (I strongly recommend you to try this notebook on the Udacity workspace first before running it locally on your desktop/laptop, as performance might suffer in different environments)

# %%
# install package for displaying animation
# !pip install JSAnimation

# custom utilies for displaying animation, collecting rollouts and more
import pong_utils

# %matplotlib inline

# check which device is being used. 
# I recommend disabling gpu until you've made sure that the code runs
device = pong_utils.device
print("using device: ",device)
# Out:
# Requirement already satisfied: JSAnimation in /mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/site-packages (0.1)
# using device:  cuda:0

# %%
# render ai gym environment
import gym
import time

# PongDeterministic does not contain random frameskip
# so is faster to train than the vanilla Pong-v4 environment
env = gym.make('PongDeterministic-v4')

print("List of available actions: ", env.unwrapped.get_action_meanings())

# we will only use the actions 'RIGHTFIRE' = 4 and 'LEFTFIRE" = 5
# the 'FIRE' part ensures that the game starts again after losing a life
# the actions are hard-coded in pong_utils.py
# Out:
# List of available actions:  ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %% [markdown]
# # Preprocessing
# To speed up training, we can simplify the input by cropping the images and use every other pixel

# %%
import matplotlib
import matplotlib.pyplot as plt

# show what a preprocessed image looks like
env.reset()
_, _, _, _ = env.step(0)
# get a frame after 20 steps
for _ in range(20):
    frame, _, _, _ = env.step(1)

plt.subplot(1,2,1)
plt.imshow(frame)
plt.title('original image')

plt.subplot(1,2,2)
plt.title('preprocessed image')

# 80 x 80 black and white image
plt.imshow(pong_utils.preprocess_single(frame), cmap='Greys')
plt.show()

# %% [markdown]
# # Policy
#
# ## Exercise 1: Implement your policy
#
# Here, we define our policy. The input is the stack of two different frames (which captures the movement), and the output is a number $P_{\rm right}$, the probability of moving left. Note that $P_{\rm left}= 1-P_{\rm right}$

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F



# set up a convolutional neural net
# the output is the probability of moving right
# P(left) = 1-P(right)
class Policy(nn.Module):

    def __init__(self):
        super(Policy, self).__init__()
        
        
    ########
    ## 
    ## Modify your neural network
    ##
    ########
        
        # 80x80 to outputsize x outputsize
        # outputsize = (inputsize - kernel_size + stride)/stride 
        # (round up if not an integer)

        # output = 20x20 here
        self.conv1 = nn.Conv2d(2, 4, kernel_size=4, stride=2, bias=False)        
        self.conv2 = nn.Conv2d(4, 32, kernel_size=5, stride=2, bias=False)
        self.size=10368
        
        # 1 fully connected layer
        self.fc1 = nn.Linear(self.size, 128, bias=True)
        self.fc2 = nn.Linear(128, 1, bias=True)
        self.sig = nn.Sigmoid()
        
    def forward(self, x):
        
    ########
    ## 
    ## Modify your neural network
    ##
    ########
    
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        # flatten the tensor
        x = x.view(-1,self.size)
        x = F.relu(self.fc1(x))
        x = self.sig(self.fc2(x))
        return x

# use your own policy!
# policy=Policy().to(device)

policy=pong_utils.Policy().to(device)

# we use the adam optimizer with learning rate 2e-4
# optim.SGD is also possible
import torch.optim as optim
optimizer = optim.Adam(policy.parameters(), lr=1e-4)

# %% [markdown]
# # Game visualization
# pong_utils contain a play function given the environment and a policy. An optional preprocess function can be supplied. Here we define a function that plays a game and shows learning progress

# %%
pong_utils.play(env, policy, time=100) 
# try to add the option "preprocess=pong_utils.preprocess_single"
# to see what the agent sees
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgPVSSNUTLVZHQZVUD">
#     <br>
#     <input id="_anim_sliderPVSSNUTLVZHQZVUD" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animPVSSNUTLVZHQZVUD.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animPVSSNUTLVZHQZVUD.slower()">&#8211;</button>
#     <button onclick="animPVSSNUTLVZHQZVUD.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animPVSSNUTLVZHQZVUD.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectPVSSNUTLVZHQZVUD" class="anim_control">
#     <input type="radio" name="state" value="once" checked> Once </input>
#     <input type="radio" name="state" value="loop" > Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgPVSSNUTLVZHQZVUD";
#     var slider_id = "_anim_sliderPVSSNUTLVZHQZVUD";
#     var loop_select_id = "_anim_loop_selectPVSSNUTLVZHQZVUD";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# # Rollout
# Before we start the training, we need to collect samples. To make things efficient we use parallelized environments to collect multiple examples at once

# %%
envs = pong_utils.parallelEnv('PongDeterministic-v4', n=4, seed=12345)
prob, state, action, reward = pong_utils.collect_trajectories(envs, policy, tmax=100)
# Out:
# Process Process-1:
# Process Process-3:
# Process Process-2:
# Process Process-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
print(reward)
# Out:
# [array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([-1., -1.,  0., -1.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([ 0.,  0., -1.,  0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([-1., -1.,  0., -1.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([-1., -1.,  0., -1.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 1., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([-1., -1.,  0.,  0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([-1., -1.,  0.,  0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.]), array([0., 0., 0., 0.])]

# %% [markdown]
# # Function Definitions
# Here you will define key functions for training.
#
# ## Exercise 2: write your own function for training
# (this is the same as policy_loss except the negative sign)
#
# ### REINFORCE
# you have two choices (usually it's useful to divide by the time since we've normalized our rewards and the time of each trajectory is fixed)
#
# 1. $\frac{1}{T}\sum^T_t R_{t}^{\rm future}\log(\pi_{\theta'}(a_t|s_t))$
# 2. $\frac{1}{T}\sum^T_t R_{t}^{\rm future}\frac{\pi_{\theta'}(a_t|s_t)}{\pi_{\theta}(a_t|s_t)}$ where $\theta'=\theta$ and make sure that the no_grad is enabled when performing the division

# %%
import numpy as np
from pong_utils import RIGHT, LEFT
'''
def surrogate(policy, old_probs, states, actions, rewards,
              discount = 0.995, beta=0.01):

    ########
    ## 
    ## WRITE YOUR OWN CODE HERE
    ##
    ########
    
    actions = torch.tensor(actions, dtype=torch.int8, device=device)

    
    # convert states to policy (or probability)
    new_probs = pong_utils.states_to_prob(policy, states)
    new_probs = torch.where(actions == pong_utils.RIGHT, new_probs, 1.0-new_probs)

    # include a regularization term
    # this steers new_policy towards 0.5
    # which prevents policy to become exactly 0 or 1
    # this helps with exploration
    # add in 1.e-10 to avoid log(0) which gives nan
    entropy = -(new_probs*torch.log(old_probs+1.e-10)+ \
        (1.0-new_probs)*torch.log(1.0-old_probs+1.e-10))

    return torch.mean(beta*entropy)
'''

# return sum of log-prob divided by T
# same thing as -policy_loss
def surrogate(policy, old_probs, states, actions, rewards,
              discount = 0.995, beta=0.01):

    discount = discount**np.arange(len(rewards))
    rewards = np.asarray(rewards)*discount[:,np.newaxis]
    
    # convert rewards to future rewards
    rewards_future = rewards[::-1].cumsum(axis=0)[::-1]
    
    mean = np.mean(rewards_future, axis=1)
    std = np.std(rewards_future, axis=1) + 1.0e-10

    rewards_normalized = (rewards_future - mean[:,np.newaxis])/std[:,np.newaxis]
    
    # convert everything into pytorch tensors and move to gpu if available
    actions = torch.tensor(actions, dtype=torch.int8, device=device)
    old_probs = torch.tensor(old_probs, dtype=torch.float, device=device)
    rewards = torch.tensor(rewards_normalized, dtype=torch.float, device=device)
    
    # convert states to policy (or probability)
    new_probs = pong_utils.states_to_prob(policy, states)
    new_probs = torch.where(actions == RIGHT, new_probs, 1.0-new_probs)    
    
    log_new_probs = torch.log(new_probs + 1e-10)

    #ratio = new_probs/old_probs

    # include a regularization term
    # this steers new_policy towards 0.5
    # add in 1.e-10 to avoid log(0) which gives nan
    #entropy = -(new_probs*torch.log(old_probs+1.e-10)+ \
    #    (1.0-new_probs)*torch.log(1.0-old_probs+1.e-10))
    
    L = torch.mean(log_new_probs*rewards)
    
    return L

Lsur= surrogate(policy, prob, state, action, reward)

print(Lsur)
# Out:
# tensor(1.00000e-03 *
#        2.4428, device='cuda:0')

# %% [markdown]
# # Training
# We are now ready to train our policy!
# WARNING: make sure to turn on GPU, which also enables multicore processing. It may take up to 45 minutes even with GPU enabled, otherwise it will take much longer!

# %%
from parallelEnv import parallelEnv
import numpy as np
# WARNING: running through all 800 episodes will take 30-45 minutes

# training loop max iterations
episode = 500
# episode = 800

# widget bar to display progress
# !pip install progressbar
import progressbar as pb
widget = ['training loop: ', pb.Percentage(), ' ', 
          pb.Bar(), ' ', pb.ETA() ]
timer = pb.ProgressBar(widgets=widget, maxval=episode).start()

# initialize environment
envs = parallelEnv('PongDeterministic-v4', n=8, seed=1234)

discount_rate = .99
beta = .01
tmax = 320

# keep track of progress
mean_rewards = []

for e in range(episode):

    # collect trajectories
    old_probs, states, actions, rewards = \
        pong_utils.collect_trajectories(envs, policy, tmax=tmax)
        
    total_rewards = np.sum(rewards, axis=0)

    # this is the SOLUTION!
    # use your own surrogate function
    L = -surrogate(policy, old_probs, states, actions, rewards, beta=beta)
    
    #L = -pong_utils.surrogate(policy, old_probs, states, actions, rewards, beta=beta)
    optimizer.zero_grad()
    L.backward()
    optimizer.step()
    del L
        
    # the regulation term also reduces
    # this reduces exploration in later runs
    beta*=.995
    
    # get the average reward of the parallel environments
    mean_rewards.append(np.mean(total_rewards))
    
    # display some progress every 20 iterations
    if (e+1)%20 ==0 :
        print("Episode: {0:d}, score: {1:f}".format(e+1,np.mean(total_rewards)))
        print(total_rewards)
        
    # update progress widget bar
    timer.update(e+1)
    
timer.finish()
# Out:
# Requirement already satisfied: progressbar in /mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/site-packages (2.5)
# training loop:   4% |#                                          | ETA:  0:28:29
# Episode: 20, score: -14.125000
# [-16. -12. -16. -14. -12. -15. -16. -12.]
# training loop:   8% |###                                        | ETA:  0:26:25
# Episode: 40, score: -13.750000
# [-12. -14. -15. -12. -14. -14. -14. -15.]
# training loop:  12% |#####                                      | ETA:  0:25:13
# Episode: 60, score: -14.125000
# [-11. -15. -15. -16. -12. -16. -13. -15.]
# training loop:  16% |######                                     | ETA:  0:24:02
# Episode: 80, score: -14.875000
# [-17. -16. -14. -16. -15. -13. -13. -15.]
# training loop:  20% |########                                   | ETA:  0:22:48
# Episode: 100, score: -15.125000
# [-16. -16. -16. -14. -16. -16. -12. -15.]
# Process Process-34: |#########                                  | ETA:  0:22:17
# Process Process-31:
# Process Process-32:
# Process Process-29:
# Process Process-33:
# Process Process-35:
# Process Process-36:
# Process Process-30:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 104, in worker
#     cmd, data = remote.recv()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a7e577b29cee> in <module>()
#      27
#      28     # collect trajectories
# ---> 29     old_probs, states, actions, rewards =         pong_utils.collect_trajectories(envs, policy, tmax=tmax)
#      30
#      31     total_rewards = np.sum(rewards, axis=0)
#
# /mnt/ExtUbuntu456G/github/drlnd/reinforce/pong_utils.py in collect_trajectories(envs, policy, tmax, nrand)
#     131         # we take one action and skip game forward
#     132         fr1, re1, is_done, _ = envs.step(action)
# --> 133         fr2, re2, is_done, _ = envs.step([0]*n)
#     134
#     135         reward = re1 + re2
#
# /mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py in step(self, actions)
#      84         """
#      85         self.step_async(actions)
# ---> 86         return self.step_wait()
#      87
#      88     def render(self, mode='human'):
#
# /mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py in step_wait(self)
#     160
#     161     def step_wait(self):
# --> 162         results = [remote.recv() for remote in self.remotes]
#     163         self.waiting = False
#     164         obs, rews, dones, infos = zip(*results)
#
# /mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py in <listcomp>(.0)
#     160
#     161     def step_wait(self):
# --> 162         results = [remote.recv() for remote in self.remotes]
#     163         self.waiting = False
#     164         obs, rews, dones, infos = zip(*results)
#
# /mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# /mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# /mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 106, in worker
#     ob, reward, done, info = env.step(data)
#   File "/mnt/ExtUbuntu456G/github/drlnd/reinforce/parallelEnv.py", line 106, in worker
#     ob, reward, done, info = env.step(data)
#   File "/mnt/ExtUbuntu456G/dropbox-git/drlnd/gym/gym/wrappers/time_limit.py", line 31, in step
#     observation, reward, done, info = self.env.step(action)
#   File "/mnt/ExtUbuntu456G/dropbox-git/drlnd/gym/gym/wrappers/time_limit.py", line 31, in step
#     observation, reward, done, info = self.env.step(action)
#   File "/mnt/ExtUbuntu456G/dropbox-git/drlnd/gym/gym/envs/atari/atari_env.py", line 75, in step
#     reward += self.ale.act(action)
#   File "/mnt/ExtUbuntu456G/dropbox-git/drlnd/gym/gym/envs/atari/atari_env.py", line 75, in step
#     reward += self.ale.act(action)
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/site-packages/atari_py/ale_python_interface.py", line 136, in act
#     return ale_lib.act(self.obj, int(action))
#   File "/mnt/ExtUbuntu456G/anaconda3/envs/drlnd/lib/python3.6/site-packages/atari_py/ale_python_interface.py", line 136, in act
#     return ale_lib.act(self.obj, int(action))
# KeyboardInterrupt
# KeyboardInterrupt

# %%
# play game after training!
pong_utils.play(env, policy, time=2000)

# %%
plt.plot(mean_rewards)

# %%
# save your policy!
torch.save(policy, 'REINFORCE.policy')

# load your policy if needed
# policy = torch.load('REINFORCE.policy')

# try and test out the solution!
# policy = torch.load('PPO_solution.policy')

# %%
policy = torch.load('REINFORCE_solution.policy')
print(type(policy))
print(dir(policy))
print(policy.conv1)
print(policy.conv2)
print(policy.fc1)
print(policy.fc2)

# %%
policy = torch.load('PPO_solution.policy')
print(type(policy))
print(dir(policy))
print(policy.conv1)
print(policy.conv2)
print(policy.fc1)
print(policy.fc2)
